# %%
import numpy as np
from numpy import loadtxt, savetxt

import matplotlib.pyplot as plt

from skopt.space import Space
from skopt.space.space import Real
from skopt.sampler import Lhs
# Out:
# C:\Users\lowki\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\lowki\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\lowki\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
np.set_printoptions(precision=1, suppress=True)

n_samples = 24

space = Space([Real(5, 40),
               Real(200, 280),
               Real(0.6, 1.8),
               Real(1.5, 4),
               Real(0, 2)])

lhs = Lhs(criterion="maximin", iterations=10000)
x = lhs.generate(space.dimensions, n_samples)
x = np.array(x)
x[:,1] = np.round(x[:,1], 0)
x
# Out:
# array([[ 13.2, 242. ,   1.7,   2.6,   0.3],
#        [  8.5, 237. ,   1.4,   2.7,   0.9],
#        [ 23.3, 256. ,   0.6,   2.8,   0.8],
#        [ 29.6, 263. ,   0.8,   2.2,   1.5],
#        [ 14.5, 202. ,   1.1,   3.7,   1.2],
#        [ 33.8, 245. ,   1.1,   3.1,   1.8],
#        [ 25.8, 211. ,   1.2,   3.5,   0.4],
#        [  7.7, 219. ,   0.9,   2. ,   1.9],
#        [ 26.9, 205. ,   1.2,   1.6,   0.2],
#        [ 32. , 227. ,   0.9,   2.9,   0.1],
#        [ 16.8, 221. ,   1.6,   3. ,   1.7],
#        [  5.9, 226. ,   1. ,   3.9,   0.4],
#        [ 38.9, 251. ,   1.7,   3.3,   1.6],
#        [ 37.5, 265. ,   1.5,   1.9,   0.7],
#        [ 31.2, 248. ,   1.8,   2.1,   1.6],
#        [ 18.3, 215. ,   1. ,   2.4,   1.3],
#        [ 36.2, 258. ,   1.5,   3.6,   0.5],
#        [ 20. , 277. ,   0.7,   3.2,   0.1],
#        [ 22.3, 267. ,   1.4,   2.3,   1.1],
#        [ 35.1, 277. ,   1.6,   2.5,   1.9],
#        [ 16.4, 271. ,   1.3,   3.4,   1.4],
#        [ 11.7, 210. ,   0.7,   1.5,   0.9],
#        [ 25.3, 234. ,   0.8,   1.7,   0.6],
#        [ 10.6, 232. ,   1.3,   3.9,   1. ]])

# %%
np.savetxt('sampling.csv', x, delimiter=',')
